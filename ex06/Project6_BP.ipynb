# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class Network:
    rate = 0.1     # 学習率
    decay = 0.1    # 学習率減衰
    per = 50       # 何エポックごとに学習率を減衰させるか
 
    epsilon = 1.0  # シグモイド関数の傾き
 
    def __init__(self, *args):
        self.layers = list(args) 
        self.weights = ([])       
        self.patterns = ([])      
        self.labels = ([])       
        self.outputs = ([])     
 
    def init_weights(self, a=0.0, b=1.0):
        for i in range(len(self.layers)):
            if i + 1 >= len(self.layers):
                break
            self.weights.append((b - a) * np.random.rand(self.layers[i + 1], self.layers[i]) + a)
 
    def load_iris(self):
        data = open('iris.data', 'r')
        lines = data.read().split()
        dataset = ([])
 
        for line in lines:
            pattern = line.split(',')
            dataset.append(pattern)
        data.close()
        #print(dataset)
 
        for i,pattern in enumerate(dataset):
            self.patterns.append(list(map(float, pattern[0:-1])))
            # setosaは0番目ニューロン、versicolorは1番目ニューロン、virginicaは2番目ニューロンが担当する
            if pattern[-1] == 'Iris-setosa':
                self.labels.append(0)
            elif pattern[-1] == 'Iris-versicolor':
                self.labels.append(1)
            else:
                self.labels.append(2)

    @staticmethod
    def input_sum(inputs, weights):
        """
        前ニューロンからの入力和を返す関数．式(1)
        :param inputs:
        :param weights:
        :return inputs dot weights (float):
        """
        return np.dot(inputs, weights)
 
    def output(self, inputs, weights):
        """
        ニューロンの出力を返す関数．式(2)
        :param inputs:
        :param weights:
        :return (0, 1):
        """
        return self.sigmoid(self.input_sum(inputs, weights))
 
    def sigmoid(self, x):
        """
        シグモイド関数　式(3)
        :param x:
        :return:
        """
        return 1.0/(1.0 + np.exp(-self.epsilon * x))
 
    def forward(self, pattern):
        """
        return 出力層ニューロンの出力値ベクトル [0,1]:
        """
        self.outputs.clear()  
 
        out = ([])  
        self.outputs.append(pattern)  
 
        for layer in range(len(self.layers)):
            out = ([])
            if layer == 1:  
                for n in range(self.layers[layer]):
                    out.append(self.output(pattern, self.weights[layer-1][n]))
 
                self.outputs.append(out)  
 
            elif layer > 1: 
                for n in range(self.layers[layer]):
                    out.append(self.output(self.outputs[-1], self.weights[layer-1][n]))
 
                self.outputs.append(out) 
 
        return out
 
    def backward(self, pattern):
        """
        BP
        """
        deltas = self.calc_delta(pattern)
        for l in reversed(range(1, len(self.layers))):
            for j, jj in enumerate(self.outputs[l]):
                for i, ii in enumerate(self.outputs[l-1]):
                    self.weights[l-1][j][i] += self.rate * deltas[l-1][j] * ii 
 
    def calc_delta(self, pattern):
        teacher = ([0.1, 0.1, 0.1])
        teacher[self.labels[pattern]] = 0.9
        deltas = ([])
 
        for l in reversed(range(1, len(self.layers))): 
            tmp_delta = ([])
            for j in range(self.layers[l]):
                if l == len(self.layers) - 1:
 
                    delta = self.epsilon * \
                            (teacher[j] - self.outputs[l][j]) * \
                            self.outputs[l][j] * (1 - self.outputs[l][j])
 
                    tmp_delta.append(delta)
 
                else: 
                    t_weights = np.array(self.weights[l]).T
                    delta = self.epsilon * \
                            self.outputs[l][j] * (1 - self.outputs[l][j]) * \
                            np.dot(deltas[-1], t_weights[j])
 
                    tmp_delta.append(delta)
 
            deltas.append(tmp_delta)
 
        return deltas[::-1]
 
    def train(self, epoch):
        """
        訓練関数
        :param epoch:
        :return:
        """
        errors = ([])
        for e in range(epoch):
            error = 100 - self.test()
            for p, pat in enumerate(self.patterns):
 
                self.forward(pat)
 
                self.backward(p)
 
            print(str(e+1) + ' / ' + str(epoch) + ' epoch.' + ' [ error: ' + str(error) + ' ]')
 
            if (e+1) % self.per == 0:
                self.rate *= self.decay
 
            errors.append(error) 
 
        plt.xlabel('epochs')
        plt.ylabel('error (%)')
        plt.plot(errors)
        plt.savefig('error.png', dpi=300)
 
    def test(self):
        """
        テスト関数
        :return: accuracy (%)
        """
        correct = 0
        for p in range(len(self.patterns)):
            self.forward(self.patterns[p])
            max = 0
            ans = -1
           
            for o, out in enumerate(self.outputs[len(self.layers)-1]):
                if max < out:
                    max = out
                    ans = o
            
            if ans == self.labels[p]:
                correct += 1
 
        accuracy = correct / len(self.patterns) * 100
        return accuracy

# %%
if __name__ == '__main__':
    net = Network(4, 20, 3)
    net.init_weights(-1.0, 1.0)
    net.load_iris()
    net.train(200)
    acc = net.test()
    print('Accuracy: ' + str(acc) + '%')
# Out:
# 1 / 200 epoch. [ error: 66.66666666666667 ]
# 2 / 200 epoch. [ error: 66.66666666666667 ]
# 3 / 200 epoch. [ error: 66.66666666666667 ]
# 4 / 200 epoch. [ error: 66.66666666666667 ]
# 5 / 200 epoch. [ error: 66.66666666666667 ]
# 6 / 200 epoch. [ error: 66.66666666666667 ]
# 7 / 200 epoch. [ error: 54.0 ]
# 8 / 200 epoch. [ error: 34.0 ]
# 9 / 200 epoch. [ error: 33.33333333333334 ]
# 10 / 200 epoch. [ error: 33.33333333333334 ]
# 11 / 200 epoch. [ error: 33.33333333333334 ]
# 12 / 200 epoch. [ error: 33.33333333333334 ]
# 13 / 200 epoch. [ error: 33.33333333333334 ]
# 14 / 200 epoch. [ error: 33.33333333333334 ]
# 15 / 200 epoch. [ error: 33.33333333333334 ]
# 16 / 200 epoch. [ error: 33.33333333333334 ]
# 17 / 200 epoch. [ error: 33.33333333333334 ]
# 18 / 200 epoch. [ error: 33.33333333333334 ]
# 19 / 200 epoch. [ error: 33.33333333333334 ]
# 20 / 200 epoch. [ error: 33.33333333333334 ]
# 21 / 200 epoch. [ error: 33.33333333333334 ]
# 22 / 200 epoch. [ error: 33.33333333333334 ]
# 23 / 200 epoch. [ error: 33.33333333333334 ]
# 24 / 200 epoch. [ error: 33.33333333333334 ]
# 25 / 200 epoch. [ error: 33.33333333333334 ]
# 26 / 200 epoch. [ error: 33.33333333333334 ]
# 27 / 200 epoch. [ error: 33.33333333333334 ]
# 28 / 200 epoch. [ error: 32.0 ]
# 29 / 200 epoch. [ error: 32.0 ]
# 30 / 200 epoch. [ error: 32.0 ]
# 31 / 200 epoch. [ error: 32.0 ]
# 32 / 200 epoch. [ error: 32.0 ]
# 33 / 200 epoch. [ error: 32.0 ]
# 34 / 200 epoch. [ error: 32.0 ]
# 35 / 200 epoch. [ error: 31.33333333333333 ]
# 36 / 200 epoch. [ error: 31.33333333333333 ]
# 37 / 200 epoch. [ error: 30.666666666666657 ]
# 38 / 200 epoch. [ error: 29.33333333333333 ]
# 39 / 200 epoch. [ error: 27.33333333333333 ]
# 40 / 200 epoch. [ error: 26.0 ]
# 41 / 200 epoch. [ error: 25.33333333333333 ]
# 42 / 200 epoch. [ error: 24.0 ]
# 43 / 200 epoch. [ error: 24.0 ]
# 44 / 200 epoch. [ error: 24.0 ]
# 45 / 200 epoch. [ error: 24.0 ]
# 46 / 200 epoch. [ error: 23.33333333333333 ]
# 47 / 200 epoch. [ error: 22.66666666666667 ]
# 48 / 200 epoch. [ error: 21.333333333333343 ]
# 49 / 200 epoch. [ error: 20.66666666666667 ]
# 50 / 200 epoch. [ error: 20.66666666666667 ]
# 51 / 200 epoch. [ error: 20.0 ]
# 52 / 200 epoch. [ error: 6.0 ]
# 53 / 200 epoch. [ error: 6.0 ]
# 54 / 200 epoch. [ error: 6.0 ]
# 55 / 200 epoch. [ error: 6.0 ]
# 56 / 200 epoch. [ error: 6.0 ]
# 57 / 200 epoch. [ error: 6.0 ]
# 58 / 200 epoch. [ error: 6.0 ]
# 59 / 200 epoch. [ error: 6.0 ]
# 60 / 200 epoch. [ error: 6.0 ]
# 61 / 200 epoch. [ error: 6.0 ]
# 62 / 200 epoch. [ error: 6.0 ]
# 63 / 200 epoch. [ error: 6.0 ]
# 64 / 200 epoch. [ error: 6.0 ]
# 65 / 200 epoch. [ error: 6.0 ]
# 66 / 200 epoch. [ error: 6.0 ]
# 67 / 200 epoch. [ error: 6.0 ]
# 68 / 200 epoch. [ error: 6.0 ]
# 69 / 200 epoch. [ error: 6.0 ]
# 70 / 200 epoch. [ error: 6.0 ]
# 71 / 200 epoch. [ error: 6.0 ]
# 72 / 200 epoch. [ error: 6.0 ]
# 73 / 200 epoch. [ error: 6.0 ]
# 74 / 200 epoch. [ error: 6.0 ]
# 75 / 200 epoch. [ error: 6.0 ]
# 76 / 200 epoch. [ error: 6.0 ]
# 77 / 200 epoch. [ error: 6.0 ]
# 78 / 200 epoch. [ error: 6.0 ]
# 79 / 200 epoch. [ error: 6.0 ]
# 80 / 200 epoch. [ error: 6.0 ]
# 81 / 200 epoch. [ error: 6.0 ]
# 82 / 200 epoch. [ error: 6.0 ]
# 83 / 200 epoch. [ error: 6.0 ]
# 84 / 200 epoch. [ error: 6.0 ]
# 85 / 200 epoch. [ error: 6.0 ]
# 86 / 200 epoch. [ error: 6.0 ]
# 87 / 200 epoch. [ error: 6.0 ]
# 88 / 200 epoch. [ error: 6.0 ]
# 89 / 200 epoch. [ error: 5.333333333333329 ]
# 90 / 200 epoch. [ error: 5.333333333333329 ]
# 91 / 200 epoch. [ error: 5.333333333333329 ]
# 92 / 200 epoch. [ error: 5.333333333333329 ]
# 93 / 200 epoch. [ error: 5.333333333333329 ]
# 94 / 200 epoch. [ error: 5.333333333333329 ]
# 95 / 200 epoch. [ error: 5.333333333333329 ]
# 96 / 200 epoch. [ error: 5.333333333333329 ]
# 97 / 200 epoch. [ error: 5.333333333333329 ]
# 98 / 200 epoch. [ error: 5.333333333333329 ]
# 99 / 200 epoch. [ error: 5.333333333333329 ]
# 100 / 200 epoch. [ error: 5.333333333333329 ]
# 101 / 200 epoch. [ error: 4.666666666666657 ]
# 102 / 200 epoch. [ error: 4.666666666666657 ]
# 103 / 200 epoch. [ error: 4.0 ]
# 104 / 200 epoch. [ error: 3.3333333333333286 ]
# 105 / 200 epoch. [ error: 2.666666666666657 ]
# 106 / 200 epoch. [ error: 2.666666666666657 ]
# 107 / 200 epoch. [ error: 2.666666666666657 ]
# 108 / 200 epoch. [ error: 2.666666666666657 ]
# 109 / 200 epoch. [ error: 2.666666666666657 ]
# 110 / 200 epoch. [ error: 2.666666666666657 ]
# 111 / 200 epoch. [ error: 2.666666666666657 ]
# 112 / 200 epoch. [ error: 2.666666666666657 ]
# 113 / 200 epoch. [ error: 2.666666666666657 ]
# 114 / 200 epoch. [ error: 2.666666666666657 ]
# 115 / 200 epoch. [ error: 2.666666666666657 ]
# 116 / 200 epoch. [ error: 2.666666666666657 ]
# 117 / 200 epoch. [ error: 2.666666666666657 ]
# 118 / 200 epoch. [ error: 2.666666666666657 ]
# 119 / 200 epoch. [ error: 2.666666666666657 ]
# 120 / 200 epoch. [ error: 2.666666666666657 ]
# 121 / 200 epoch. [ error: 2.666666666666657 ]
# 122 / 200 epoch. [ error: 2.666666666666657 ]
# 123 / 200 epoch. [ error: 2.666666666666657 ]
# 124 / 200 epoch. [ error: 2.666666666666657 ]
# 125 / 200 epoch. [ error: 2.666666666666657 ]
# 126 / 200 epoch. [ error: 2.666666666666657 ]
# 127 / 200 epoch. [ error: 2.666666666666657 ]
# 128 / 200 epoch. [ error: 2.666666666666657 ]
# 129 / 200 epoch. [ error: 2.666666666666657 ]
# 130 / 200 epoch. [ error: 2.666666666666657 ]
# 131 / 200 epoch. [ error: 2.666666666666657 ]
# 132 / 200 epoch. [ error: 2.666666666666657 ]
# 133 / 200 epoch. [ error: 2.666666666666657 ]
# 134 / 200 epoch. [ error: 2.666666666666657 ]
# 135 / 200 epoch. [ error: 2.666666666666657 ]
# 136 / 200 epoch. [ error: 2.666666666666657 ]
# 137 / 200 epoch. [ error: 2.666666666666657 ]
# 138 / 200 epoch. [ error: 2.666666666666657 ]
# 139 / 200 epoch. [ error: 2.666666666666657 ]
# 140 / 200 epoch. [ error: 2.666666666666657 ]
# 141 / 200 epoch. [ error: 2.666666666666657 ]
# 142 / 200 epoch. [ error: 2.666666666666657 ]
# 143 / 200 epoch. [ error: 2.666666666666657 ]
# 144 / 200 epoch. [ error: 2.666666666666657 ]
# 145 / 200 epoch. [ error: 2.666666666666657 ]
# 146 / 200 epoch. [ error: 2.666666666666657 ]
# 147 / 200 epoch. [ error: 2.666666666666657 ]
# 148 / 200 epoch. [ error: 2.666666666666657 ]
# 149 / 200 epoch. [ error: 2.666666666666657 ]
# 150 / 200 epoch. [ error: 2.666666666666657 ]
# 151 / 200 epoch. [ error: 2.666666666666657 ]
# 152 / 200 epoch. [ error: 2.666666666666657 ]
# 153 / 200 epoch. [ error: 2.666666666666657 ]
# 154 / 200 epoch. [ error: 2.666666666666657 ]
# 155 / 200 epoch. [ error: 2.666666666666657 ]
# 156 / 200 epoch. [ error: 2.666666666666657 ]
# 157 / 200 epoch. [ error: 2.666666666666657 ]
# 158 / 200 epoch. [ error: 2.666666666666657 ]
# 159 / 200 epoch. [ error: 2.666666666666657 ]
# 160 / 200 epoch. [ error: 2.666666666666657 ]
# 161 / 200 epoch. [ error: 2.666666666666657 ]
# 162 / 200 epoch. [ error: 2.666666666666657 ]
# 163 / 200 epoch. [ error: 2.666666666666657 ]
# 164 / 200 epoch. [ error: 2.666666666666657 ]
# 165 / 200 epoch. [ error: 2.666666666666657 ]
# 166 / 200 epoch. [ error: 2.666666666666657 ]
# 167 / 200 epoch. [ error: 2.666666666666657 ]
# 168 / 200 epoch. [ error: 2.666666666666657 ]
# 169 / 200 epoch. [ error: 2.666666666666657 ]
# 170 / 200 epoch. [ error: 2.666666666666657 ]
# 171 / 200 epoch. [ error: 2.666666666666657 ]
# 172 / 200 epoch. [ error: 2.666666666666657 ]
# 173 / 200 epoch. [ error: 2.666666666666657 ]
# 174 / 200 epoch. [ error: 2.666666666666657 ]
# 175 / 200 epoch. [ error: 2.666666666666657 ]
# 176 / 200 epoch. [ error: 2.666666666666657 ]
# 177 / 200 epoch. [ error: 2.666666666666657 ]
# 178 / 200 epoch. [ error: 2.666666666666657 ]
# 179 / 200 epoch. [ error: 2.666666666666657 ]
# 180 / 200 epoch. [ error: 2.666666666666657 ]
# 181 / 200 epoch. [ error: 2.666666666666657 ]
# 182 / 200 epoch. [ error: 2.666666666666657 ]
# 183 / 200 epoch. [ error: 2.666666666666657 ]
# 184 / 200 epoch. [ error: 2.666666666666657 ]
# 185 / 200 epoch. [ error: 2.666666666666657 ]
# 186 / 200 epoch. [ error: 2.666666666666657 ]
# 187 / 200 epoch. [ error: 2.666666666666657 ]
# 188 / 200 epoch. [ error: 2.666666666666657 ]
# 189 / 200 epoch. [ error: 2.666666666666657 ]
# 190 / 200 epoch. [ error: 2.666666666666657 ]
# 191 / 200 epoch. [ error: 2.666666666666657 ]
# 192 / 200 epoch. [ error: 2.666666666666657 ]
# 193 / 200 epoch. [ error: 2.666666666666657 ]
# 194 / 200 epoch. [ error: 2.666666666666657 ]
# 195 / 200 epoch. [ error: 2.666666666666657 ]
# 196 / 200 epoch. [ error: 2.666666666666657 ]
# 197 / 200 epoch. [ error: 2.666666666666657 ]
# 198 / 200 epoch. [ error: 2.666666666666657 ]
# 199 / 200 epoch. [ error: 2.666666666666657 ]
# 200 / 200 epoch. [ error: 2.666666666666657 ]
# Accuracy: 97.33333333333334%
