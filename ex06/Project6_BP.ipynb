# %% [markdown]
# # Ex06 BP algorithm
# outline
# - Import
# - Make network model
# - Train and test program

# %% [markdown]
# ### Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Make network model

# %%
class Network:
    rate = 0.1     # 学習率
    decay = 0.1    # 学習率減衰
    per = 50       # 何エポックごとに学習率を減衰させるか
 
    epsilon = 1.0  # シグモイド関数の傾き
 
    def __init__(self, *args):
        self.layers = list(args) 
        self.weights = ([])       
        self.patterns = ([])      
        self.labels = ([])       
        self.outputs = ([])     
 
    def init_weights(self, a=0.0, b=1.0):
        for i in range(len(self.layers)):
            if i + 1 >= len(self.layers):
                break
            self.weights.append((b - a) * np.random.rand(self.layers[i + 1], self.layers[i]) + a)
 
    def load_iris(self):
        data = open('iris.data', 'r')
        lines = data.read().split()
        dataset = ([])
 
        for line in lines:
            pattern = line.split(',')
            dataset.append(pattern)
        data.close()
        #print(dataset)
 
        for i,pattern in enumerate(dataset):
            self.patterns.append(list(map(float, pattern[0:-1])))
            # setosaは0番目ニューロン、versicolorは1番目ニューロン、virginicaは2番目ニューロンが担当する
            if pattern[-1] == 'Iris-setosa':
                self.labels.append(0)
            elif pattern[-1] == 'Iris-versicolor':
                self.labels.append(1)
            else:
                self.labels.append(2)

    @staticmethod
    def input_sum(inputs, weights):
        """
        前ニューロンからの入力和を返す関数．式(1)
        :param inputs:
        :param weights:
        :return inputs dot weights (float):
        """
        return np.dot(inputs, weights)
 
    def output(self, inputs, weights):
        """
        ニューロンの出力を返す関数．式(2)
        :param inputs:
        :param weights:
        :return (0, 1):
        """
        return self.sigmoid(self.input_sum(inputs, weights))
 
    def sigmoid(self, x):
        """
        シグモイド関数　式(3)
        :param x:
        :return:
        """
        return 1.0/(1.0 + np.exp(-self.epsilon * x))
 
    def forward(self, pattern):
        """
        return 出力層ニューロンの出力値ベクトル [0,1]:
        """
        self.outputs.clear()  
 
        out = ([])  
        self.outputs.append(pattern)  
 
        for layer in range(len(self.layers)):
            out = ([])
            if layer == 1:  
                for n in range(self.layers[layer]):
                    out.append(self.output(pattern, self.weights[layer-1][n]))
 
                self.outputs.append(out)  
 
            elif layer > 1: 
                for n in range(self.layers[layer]):
                    out.append(self.output(self.outputs[-1], self.weights[layer-1][n]))
 
                self.outputs.append(out) 
 
        return out
 
    def backward(self, pattern):
        """
        BP
        """
        deltas = self.calc_delta(pattern)
        for l in reversed(range(1, len(self.layers))):
            for j, jj in enumerate(self.outputs[l]):
                for i, ii in enumerate(self.outputs[l-1]):
                    self.weights[l-1][j][i] += self.rate * deltas[l-1][j] * ii 
 
    def calc_delta(self, pattern):
        teacher = ([0.1, 0.1, 0.1])
        teacher[self.labels[pattern]] = 0.9
        deltas = ([])
 
        for l in reversed(range(1, len(self.layers))): 
            tmp_delta = ([])
            for j in range(self.layers[l]):
                if l == len(self.layers) - 1:
 
                    delta = self.epsilon * \
                            (teacher[j] - self.outputs[l][j]) * \
                            self.outputs[l][j] * (1 - self.outputs[l][j])
 
                    tmp_delta.append(delta)
 
                else: 
                    t_weights = np.array(self.weights[l]).T
                    delta = self.epsilon * \
                            self.outputs[l][j] * (1 - self.outputs[l][j]) * \
                            np.dot(deltas[-1], t_weights[j])
 
                    tmp_delta.append(delta)
 
            deltas.append(tmp_delta)
 
        return deltas[::-1]
 
    def train(self, epoch):
        """
        訓練関数
        :param epoch:
        :return:
        """
        errors = ([])
        for e in range(epoch):
            error = 100 - self.test()
            for p, pat in enumerate(self.patterns):
 
                self.forward(pat)
 
                self.backward(p)
 
            print(str(e+1) + ' / ' + str(epoch) + ' epoch.' + ' [ error: ' + str(error) + ' ]')
 
            if (e+1) % self.per == 0:
                self.rate *= self.decay
 
            errors.append(error) 
 
        plt.xlabel('epochs')
        plt.ylabel('error (%)')
        plt.plot(errors)
        #plt.savefig('error.png', dpi=300)
 
    def test(self):
        """
        テスト関数
        :return: accuracy (%)
        """
        correct = 0
        for p in range(len(self.patterns)):
            self.forward(self.patterns[p])
            max = 0
            ans = -1
           
            for o, out in enumerate(self.outputs[len(self.layers)-1]):
                if max < out:
                    max = out
                    ans = o
            
            if ans == self.labels[p]:
                correct += 1
 
        accuracy = correct / len(self.patterns) * 100
        return accuracy

# %% [markdown]
# ### Train and test program

# %%
if __name__ == '__main__':
    net = Network(4, 20, 3)
    net.init_weights(-1.0, 1.0)
    net.load_iris()
    net.train(200)
    acc = net.test()
    print('Accuracy: ' + str(acc) + '%')
# Out:
# 1 / 200 epoch. [ error: 66.66666666666667 ]
# 2 / 200 epoch. [ error: 66.66666666666667 ]
# 3 / 200 epoch. [ error: 66.66666666666667 ]
# 4 / 200 epoch. [ error: 45.333333333333336 ]
# 5 / 200 epoch. [ error: 34.0 ]
# 6 / 200 epoch. [ error: 33.33333333333334 ]
# 7 / 200 epoch. [ error: 33.33333333333334 ]
# 8 / 200 epoch. [ error: 33.33333333333334 ]
# 9 / 200 epoch. [ error: 33.33333333333334 ]
# 10 / 200 epoch. [ error: 33.33333333333334 ]
# 11 / 200 epoch. [ error: 33.33333333333334 ]
# 12 / 200 epoch. [ error: 33.33333333333334 ]
# 13 / 200 epoch. [ error: 33.33333333333334 ]
# 14 / 200 epoch. [ error: 33.33333333333334 ]
# 15 / 200 epoch. [ error: 33.33333333333334 ]
# 16 / 200 epoch. [ error: 33.33333333333334 ]
# 17 / 200 epoch. [ error: 33.33333333333334 ]
# 18 / 200 epoch. [ error: 33.33333333333334 ]
# 19 / 200 epoch. [ error: 33.33333333333334 ]
# 20 / 200 epoch. [ error: 33.33333333333334 ]
# 21 / 200 epoch. [ error: 33.33333333333334 ]
# 22 / 200 epoch. [ error: 33.33333333333334 ]
# 23 / 200 epoch. [ error: 33.33333333333334 ]
# 24 / 200 epoch. [ error: 33.33333333333334 ]
# 25 / 200 epoch. [ error: 33.33333333333334 ]
# 26 / 200 epoch. [ error: 33.33333333333334 ]
# 27 / 200 epoch. [ error: 33.33333333333334 ]
# 28 / 200 epoch. [ error: 33.33333333333334 ]
# 29 / 200 epoch. [ error: 33.33333333333334 ]
# 30 / 200 epoch. [ error: 33.33333333333334 ]
# 31 / 200 epoch. [ error: 32.66666666666667 ]
# 32 / 200 epoch. [ error: 32.0 ]
# 33 / 200 epoch. [ error: 32.0 ]
# 34 / 200 epoch. [ error: 32.0 ]
# 35 / 200 epoch. [ error: 32.0 ]
# 36 / 200 epoch. [ error: 32.0 ]
# 37 / 200 epoch. [ error: 32.0 ]
# 38 / 200 epoch. [ error: 32.0 ]
# 39 / 200 epoch. [ error: 32.0 ]
# 40 / 200 epoch. [ error: 32.0 ]
# 41 / 200 epoch. [ error: 32.0 ]
# 42 / 200 epoch. [ error: 32.0 ]
# 43 / 200 epoch. [ error: 30.666666666666657 ]
# 44 / 200 epoch. [ error: 29.33333333333333 ]
# 45 / 200 epoch. [ error: 29.33333333333333 ]
# 46 / 200 epoch. [ error: 28.0 ]
# 47 / 200 epoch. [ error: 26.66666666666667 ]
# 48 / 200 epoch. [ error: 26.0 ]
# 49 / 200 epoch. [ error: 25.33333333333333 ]
# 50 / 200 epoch. [ error: 24.66666666666667 ]
# 51 / 200 epoch. [ error: 24.66666666666667 ]
# 52 / 200 epoch. [ error: 11.333333333333329 ]
# 53 / 200 epoch. [ error: 10.0 ]
# 54 / 200 epoch. [ error: 10.0 ]
# 55 / 200 epoch. [ error: 9.333333333333343 ]
# 56 / 200 epoch. [ error: 9.333333333333343 ]
# 57 / 200 epoch. [ error: 8.666666666666671 ]
# 58 / 200 epoch. [ error: 8.666666666666671 ]
# 59 / 200 epoch. [ error: 8.666666666666671 ]
# 60 / 200 epoch. [ error: 8.666666666666671 ]
# 61 / 200 epoch. [ error: 8.0 ]
# 62 / 200 epoch. [ error: 8.0 ]
# 63 / 200 epoch. [ error: 8.0 ]
# 64 / 200 epoch. [ error: 8.0 ]
# 65 / 200 epoch. [ error: 8.0 ]
# 66 / 200 epoch. [ error: 8.0 ]
# 67 / 200 epoch. [ error: 8.0 ]
# 68 / 200 epoch. [ error: 8.0 ]
# 69 / 200 epoch. [ error: 8.0 ]
# 70 / 200 epoch. [ error: 8.0 ]
# 71 / 200 epoch. [ error: 8.0 ]
# 72 / 200 epoch. [ error: 8.0 ]
# 73 / 200 epoch. [ error: 8.0 ]
# 74 / 200 epoch. [ error: 8.0 ]
# 75 / 200 epoch. [ error: 8.0 ]
# 76 / 200 epoch. [ error: 8.0 ]
# 77 / 200 epoch. [ error: 8.0 ]
# 78 / 200 epoch. [ error: 8.0 ]
# 79 / 200 epoch. [ error: 8.0 ]
# 80 / 200 epoch. [ error: 7.333333333333343 ]
# 81 / 200 epoch. [ error: 7.333333333333343 ]
# 82 / 200 epoch. [ error: 6.666666666666671 ]
# 83 / 200 epoch. [ error: 6.666666666666671 ]
# 84 / 200 epoch. [ error: 6.666666666666671 ]
# 85 / 200 epoch. [ error: 6.666666666666671 ]
# 86 / 200 epoch. [ error: 6.666666666666671 ]
# 87 / 200 epoch. [ error: 6.666666666666671 ]
# 88 / 200 epoch. [ error: 6.666666666666671 ]
# 89 / 200 epoch. [ error: 6.666666666666671 ]
# 90 / 200 epoch. [ error: 6.666666666666671 ]
# 91 / 200 epoch. [ error: 6.666666666666671 ]
# 92 / 200 epoch. [ error: 6.666666666666671 ]
# 93 / 200 epoch. [ error: 6.666666666666671 ]
# 94 / 200 epoch. [ error: 6.666666666666671 ]
# 95 / 200 epoch. [ error: 6.0 ]
# 96 / 200 epoch. [ error: 6.0 ]
# 97 / 200 epoch. [ error: 6.0 ]
# 98 / 200 epoch. [ error: 6.0 ]
# 99 / 200 epoch. [ error: 6.0 ]
# 100 / 200 epoch. [ error: 6.0 ]
# 101 / 200 epoch. [ error: 6.0 ]
# 102 / 200 epoch. [ error: 4.666666666666657 ]
# 103 / 200 epoch. [ error: 4.666666666666657 ]
# 104 / 200 epoch. [ error: 4.666666666666657 ]
# 105 / 200 epoch. [ error: 4.0 ]
# 106 / 200 epoch. [ error: 4.0 ]
# 107 / 200 epoch. [ error: 4.0 ]
# 108 / 200 epoch. [ error: 3.3333333333333286 ]
# 109 / 200 epoch. [ error: 3.3333333333333286 ]
# 110 / 200 epoch. [ error: 3.3333333333333286 ]
# 111 / 200 epoch. [ error: 3.3333333333333286 ]
# 112 / 200 epoch. [ error: 3.3333333333333286 ]
# 113 / 200 epoch. [ error: 3.3333333333333286 ]
# 114 / 200 epoch. [ error: 3.3333333333333286 ]
# 115 / 200 epoch. [ error: 3.3333333333333286 ]
# 116 / 200 epoch. [ error: 3.3333333333333286 ]
# 117 / 200 epoch. [ error: 3.3333333333333286 ]
# 118 / 200 epoch. [ error: 3.3333333333333286 ]
# 119 / 200 epoch. [ error: 3.3333333333333286 ]
# 120 / 200 epoch. [ error: 3.3333333333333286 ]
# 121 / 200 epoch. [ error: 3.3333333333333286 ]
# 122 / 200 epoch. [ error: 3.3333333333333286 ]
# 123 / 200 epoch. [ error: 3.3333333333333286 ]
# 124 / 200 epoch. [ error: 3.3333333333333286 ]
# 125 / 200 epoch. [ error: 3.3333333333333286 ]
# 126 / 200 epoch. [ error: 3.3333333333333286 ]
# 127 / 200 epoch. [ error: 3.3333333333333286 ]
# 128 / 200 epoch. [ error: 3.3333333333333286 ]
# 129 / 200 epoch. [ error: 3.3333333333333286 ]
# 130 / 200 epoch. [ error: 3.3333333333333286 ]
# 131 / 200 epoch. [ error: 3.3333333333333286 ]
# 132 / 200 epoch. [ error: 3.3333333333333286 ]
# 133 / 200 epoch. [ error: 3.3333333333333286 ]
# 134 / 200 epoch. [ error: 3.3333333333333286 ]
# 135 / 200 epoch. [ error: 3.3333333333333286 ]
# 136 / 200 epoch. [ error: 3.3333333333333286 ]
# 137 / 200 epoch. [ error: 3.3333333333333286 ]
# 138 / 200 epoch. [ error: 3.3333333333333286 ]
# 139 / 200 epoch. [ error: 3.3333333333333286 ]
# 140 / 200 epoch. [ error: 3.3333333333333286 ]
# 141 / 200 epoch. [ error: 3.3333333333333286 ]
# 142 / 200 epoch. [ error: 3.3333333333333286 ]
# 143 / 200 epoch. [ error: 3.3333333333333286 ]
# 144 / 200 epoch. [ error: 3.3333333333333286 ]
# 145 / 200 epoch. [ error: 3.3333333333333286 ]
# 146 / 200 epoch. [ error: 3.3333333333333286 ]
# 147 / 200 epoch. [ error: 3.3333333333333286 ]
# 148 / 200 epoch. [ error: 3.3333333333333286 ]
# 149 / 200 epoch. [ error: 3.3333333333333286 ]
# 150 / 200 epoch. [ error: 3.3333333333333286 ]
# 151 / 200 epoch. [ error: 3.3333333333333286 ]
# 152 / 200 epoch. [ error: 3.3333333333333286 ]
# 153 / 200 epoch. [ error: 3.3333333333333286 ]
# 154 / 200 epoch. [ error: 3.3333333333333286 ]
# 155 / 200 epoch. [ error: 3.3333333333333286 ]
# 156 / 200 epoch. [ error: 3.3333333333333286 ]
# 157 / 200 epoch. [ error: 3.3333333333333286 ]
# 158 / 200 epoch. [ error: 4.0 ]
# 159 / 200 epoch. [ error: 4.0 ]
# 160 / 200 epoch. [ error: 4.0 ]
# 161 / 200 epoch. [ error: 4.0 ]
# 162 / 200 epoch. [ error: 4.0 ]
# 163 / 200 epoch. [ error: 4.0 ]
# 164 / 200 epoch. [ error: 4.0 ]
# 165 / 200 epoch. [ error: 4.0 ]
# 166 / 200 epoch. [ error: 4.0 ]
# 167 / 200 epoch. [ error: 4.0 ]
# 168 / 200 epoch. [ error: 4.0 ]
# 169 / 200 epoch. [ error: 4.0 ]
# 170 / 200 epoch. [ error: 4.0 ]
# 171 / 200 epoch. [ error: 4.0 ]
# 172 / 200 epoch. [ error: 4.0 ]
# 173 / 200 epoch. [ error: 4.0 ]
# 174 / 200 epoch. [ error: 4.0 ]
# 175 / 200 epoch. [ error: 4.0 ]
# 176 / 200 epoch. [ error: 3.3333333333333286 ]
# 177 / 200 epoch. [ error: 3.3333333333333286 ]
# 178 / 200 epoch. [ error: 3.3333333333333286 ]
# 179 / 200 epoch. [ error: 3.3333333333333286 ]
# 180 / 200 epoch. [ error: 3.3333333333333286 ]
# 181 / 200 epoch. [ error: 3.3333333333333286 ]
# 182 / 200 epoch. [ error: 3.3333333333333286 ]
# 183 / 200 epoch. [ error: 3.3333333333333286 ]
# 184 / 200 epoch. [ error: 3.3333333333333286 ]
# 185 / 200 epoch. [ error: 3.3333333333333286 ]
# 186 / 200 epoch. [ error: 3.3333333333333286 ]
# 187 / 200 epoch. [ error: 3.3333333333333286 ]
# 188 / 200 epoch. [ error: 3.3333333333333286 ]
# 189 / 200 epoch. [ error: 3.3333333333333286 ]
# 190 / 200 epoch. [ error: 3.3333333333333286 ]
# 191 / 200 epoch. [ error: 3.3333333333333286 ]
# 192 / 200 epoch. [ error: 3.3333333333333286 ]
# 193 / 200 epoch. [ error: 3.3333333333333286 ]
# 194 / 200 epoch. [ error: 3.3333333333333286 ]
# 195 / 200 epoch. [ error: 3.3333333333333286 ]
# 196 / 200 epoch. [ error: 3.3333333333333286 ]
# 197 / 200 epoch. [ error: 3.3333333333333286 ]
# 198 / 200 epoch. [ error: 3.3333333333333286 ]
# 199 / 200 epoch. [ error: 3.3333333333333286 ]
# 200 / 200 epoch. [ error: 3.3333333333333286 ]
# Accuracy: 96.66666666666667%
